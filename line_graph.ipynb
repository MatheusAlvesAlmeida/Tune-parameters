# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %%
read_file = pd.read_csv("demofile5.txt")
read_file.to_csv("/home/gabriel/Documents/CIn/Bioinspirada/Tune-parameters/demofile5.csv")

# %%
df = pd.read_csv('demofile5.csv')['0.8014981273408239'].values.tolist()

# %%
#average of all values of df
avg = sum(df)/len(df)

# %%
#standard deviation of all values of df
std = np.std(df)

# %%
# generate graph of df subplots
fig, ax = plt.subplots()
ax.plot(df)
ax.set_title('Fitness of the best individual')
ax.set_xlabel('Generation')
ax.set_ylabel('Fitness')
ax.grid(True)
plt.show()
